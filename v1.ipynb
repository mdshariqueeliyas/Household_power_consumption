# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("household_power_consumption.txt",sep=";")
# Out:
# F:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
data.shape
# Out:
# (2075259, 9)

# %%
data.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
df_as_ts = pd.read_csv('household_power_consumption.txt',sep=';',parse_dates=["Date"],nrows=99999)

# %%
df_as_ts.head(20)
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  2006-12-16  17:24:00               4.216                 0.418  234.840
# 1  2006-12-16  17:25:00               5.360                 0.436  233.630
# 2  2006-12-16  17:26:00               5.374                 0.498  233.290
# 3  2006-12-16  17:27:00               5.388                 0.502  233.740
# 4  2006-12-16  17:28:00               3.666                 0.528  235.680
# 5  2006-12-16  17:29:00               3.520                 0.522  235.020
# 6  2006-12-16  17:30:00               3.702                 0.520  235.090
# 7  2006-12-16  17:31:00               3.700                 0.520  235.220
# 8  2006-12-16  17:32:00               3.668                 0.510  233.990
# 9  2006-12-16  17:33:00               3.662                 0.510  233.860
# 10 2006-12-16  17:34:00               4.448                 0.498  232.860
# ...

# %%
type(data.Date[0])
# Out:
# str

# %%
type(df_as_ts.index)
# Out:
# pandas.indexes.range.RangeIndex

# %%
df = df_as_ts

# %%
df.shape
# Out:
# (99999, 9)

# %%
list(df.columns.values)
# Out:
# ['Date',
#  'Time',
#  'Global_active_power',
#  'Global_reactive_power',
#  'Voltage',
#  'Global_intensity',
#  'Sub_metering_1',
#  'Sub_metering_2',
#  'Sub_metering_3']

# %%
df['Time'] = pd.to_datetime(df['Time']).dt.time

# %%
df.head()
# Out:
#         Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0 2006-12-16  17:24:00               4.216                 0.418  234.840
# 1 2006-12-16  17:25:00               5.360                 0.436  233.630
# 2 2006-12-16  17:26:00               5.374                 0.498  233.290
# 3 2006-12-16  17:27:00               5.388                 0.502  233.740
# 4 2006-12-16  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
type(df.Time[0])
# Out:
# datetime.time

# %%
df_2day = df.loc[df['Date']=="2006-12-17",:]

# %%
df_2day
# Out:
#            Date      Time Global_active_power Global_reactive_power  Voltage  \
# 396  2006-12-17  00:00:00               1.044                 0.152  242.730
# 397  2006-12-17  00:01:00               1.520                 0.220  242.200
# 398  2006-12-17  00:02:00               3.038                 0.194  240.140
# 399  2006-12-17  00:03:00               2.974                 0.194  239.970
# 400  2006-12-17  00:04:00               2.846                 0.198  240.390
# 401  2006-12-17  00:05:00               2.848                 0.198  240.590
# 402  2006-12-17  00:06:00               2.858                 0.202  241.140
# 403  2006-12-17  00:07:00               2.472                 0.208  241.620
# 404  2006-12-17  00:08:00               0.658                 0.244  243.750
# 405  2006-12-17  00:09:00               0.838                 0.334  242.090
# 406  2006-12-17  00:10:00               2.608                 0.298  239.450
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 9 columns):
# Date                     99999 non-null datetime64[ns]
# Time                     99999 non-null object
# Global_active_power      99999 non-null object
# Global_reactive_power    99999 non-null object
# Voltage                  99999 non-null object
# Global_intensity         99999 non-null object
# Sub_metering_1           99999 non-null object
# Sub_metering_2           99999 non-null object
# Sub_metering_3           99991 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 6.9+ MB

# %%
df = df.convert_objects(convert_numeric=True)
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 9 columns):
# Date                     99999 non-null datetime64[ns]
# Time                     99999 non-null object
# Global_active_power      99991 non-null float64
# Global_reactive_power    99991 non-null float64
# Voltage                  99991 non-null float64
# Global_intensity         99991 non-null float64
# Sub_metering_1           99991 non-null float64
# Sub_metering_2           99991 non-null float64
# Sub_metering_3           99991 non-null float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 6.9+ MB

# %%
plt.plot(df.loc[df['Date']=="2006-12-17",'Time'],df.loc[df['Date']=="2006-12-17",'Global_intensity'],'-')

# %%
plt.plot(df.loc[df['Date']=="2006-12-18",'Time'],df.loc[df['Date']=="2006-12-18",'Global_intensity'],'-')
#plt.figure(num=None,figsize=(20,20),dpi=100,facecolor='g',edgecolor='k')
plt.savefig('test.png',dpi=100,figsize=(200,200))

# %%
plt.plot(df.loc[df['Date']=="2006-12-19",'Time'],df.loc[df['Date']=="2006-12-19",'Global_intensity'],'-')

# %%
plt.plot(df.loc[df['Date']=="2006-12-20",'Time'],df.loc[df['Date']=="2006-12-20",'Global_intensity'],'-')

# %%
df_date = pd.DataFrame(df)

# %%
df_date.index = df['Date']

# %%
del df_date['Date']

# %%
df_date
# Out:
#                 Time  Global_active_power  Global_reactive_power  Voltage  \
# Date
# 2006-12-16  17:24:00                4.216                  0.418   234.84
# 2006-12-16  17:25:00                5.360                  0.436   233.63
# 2006-12-16  17:26:00                5.374                  0.498   233.29
# 2006-12-16  17:27:00                5.388                  0.502   233.74
# 2006-12-16  17:28:00                3.666                  0.528   235.68
# 2006-12-16  17:29:00                3.520                  0.522   235.02
# 2006-12-16  17:30:00                3.702                  0.520   235.09
# 2006-12-16  17:31:00                3.700                  0.520   235.22
# 2006-12-16  17:32:00                3.668                  0.510   233.99
# 2006-12-16  17:33:00                3.662                  0.510   233.86
# 2006-12-16  17:34:00                4.448                  0.498   232.86
# 2006-12-16  17:35:00                5.412                  0.470   232.78
# ...

# %%
df_1stday = pd.DataFrame(df["2006-12-16"])

# %%
df_1stday.index = df_1stday['Time']

# %%
del df_1stday['Time']

# %%
df_1stday
# Out:
#           Global_active_power  Global_reactive_power  Voltage  \
# Time
# 17:24:00                4.216                  0.418   234.84
# 17:25:00                5.360                  0.436   233.63
# 17:26:00                5.374                  0.498   233.29
# 17:27:00                5.388                  0.502   233.74
# 17:28:00                3.666                  0.528   235.68
# 17:29:00                3.520                  0.522   235.02
# 17:30:00                3.702                  0.520   235.09
# 17:31:00                3.700                  0.520   235.22
# 17:32:00                3.668                  0.510   233.99
# 17:33:00                3.662                  0.510   233.86
# 17:34:00                4.448                  0.498   232.86
# 17:35:00                5.412                  0.470   232.78
# 17:36:00                5.224                  0.478   232.99
# 17:37:00                5.268                  0.398   232.91
# ...

# %%
df_2ndday = pd.DataFrame(df["2006-12-17"])
df_2ndday.index = df_2ndday['Time']
del df_2ndday['Time']
df_2ndday
# Out:
#           Global_active_power  Global_reactive_power  Voltage  \
# Time
# 00:00:00                1.044                  0.152   242.73
# 00:01:00                1.520                  0.220   242.20
# 00:02:00                3.038                  0.194   240.14
# 00:03:00                2.974                  0.194   239.97
# 00:04:00                2.846                  0.198   240.39
# 00:05:00                2.848                  0.198   240.59
# 00:06:00                2.858                  0.202   241.14
# 00:07:00                2.472                  0.208   241.62
# 00:08:00                0.658                  0.244   243.75
# 00:09:00                0.838                  0.334   242.09
# 00:10:00                2.608                  0.298   239.45
# 00:11:00                2.598                  0.296   239.44
# 00:12:00                2.560                  0.286   238.71
# 00:13:00                2.526                  0.278   236.95
# ...

# %%
df_2ndday.Global_intensity.resample(rule='24H',closed='left',label='left',base=17).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-29ae0c670cce> in <module>()
# ----> 1 df_2ndday.Global_intensity.resample(rule='24H',closed='left',label='left',base=17).mean()
#
# F:\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    4210                      axis=axis, kind=kind, loffset=loffset,
#    4211                      convention=convention,
# -> 4212                      base=base, key=on, level=level)
#    4213         return _maybe_process_deprecations(r,
#    4214                                            how=how,
#
# F:\Anaconda3\lib\site-packages\pandas\tseries\resample.py in resample(obj, kind, **kwds)
#     942     """ create a TimeGrouper and return our resampler """
#     943     tg = TimeGrouper(**kwds)
# ...

# %%
df
